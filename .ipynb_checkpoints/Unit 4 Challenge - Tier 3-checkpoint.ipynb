# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %%
properties.dtypes
# Out:
# Unnamed: 0              datetime64[ns]
# City of London                  object
# Barking & Dagenham              object
# Barnet                          object
# Bexley                          object
# Brent                           object
# Bromley                         object
# Camden                          object
# Croydon                         object
# Ealing                          object
# Enfield                         object
# Greenwich                       object
# Hackney                         object
# Hammersmith & Fulham            object
# Haringey                        object
# Harrow                          object
# Havering                        object
# Hillingdon                      object
# Hounslow                        object
# Islington                       object
# Kensington & Chelsea            object
# Kingston upon Thames            object
# Lambeth                         object
# Lewisham                        object
# Merton                          object
# Newham                          object
# Redbridge                       object
# Richmond upon Thames            object
# Southwark                       object
# Sutton                          object
# Tower Hamlets                   object
# Waltham Forest                  object
# Wandsworth                      object
# Westminster                     object
# Unnamed: 34                    float64
# Inner London                    object
# Outer London                    object
# Unnamed: 37                    float64
# NORTH EAST                      object
# NORTH WEST                      object
# YORKS & THE HUMBER              object
# EAST MIDLANDS                   object
# WEST MIDLANDS                   object
# EAST OF ENGLAND                 object
# LONDON                          object
# SOUTH EAST                      object
# SOUTH WEST                      object
# Unnamed: 47                    float64
# England                         object
# dtype: object

# %%
properties.isnull().sum()
# Out:
# Unnamed: 0                1
# City of London            0
# Barking & Dagenham        0
# Barnet                    0
# Bexley                    0
# Brent                     0
# Bromley                   0
# Camden                    0
# Croydon                   0
# Ealing                    0
# Enfield                   0
# Greenwich                 0
# Hackney                   0
# Hammersmith & Fulham      0
# Haringey                  0
# Harrow                    0
# Havering                  0
# Hillingdon                0
# Hounslow                  0
# Islington                 0
# Kensington & Chelsea      0
# Kingston upon Thames      0
# Lambeth                   0
# Lewisham                  0
# Merton                    0
# Newham                    0
# Redbridge                 0
# Richmond upon Thames      0
# Southwark                 0
# Sutton                    0
# Tower Hamlets             0
# Waltham Forest            0
# Wandsworth                0
# Westminster               0
# Unnamed: 34             302
# Inner London              0
# Outer London              0
# Unnamed: 37             302
# NORTH EAST                0
# NORTH WEST                0
# YORKS & THE HUMBER        0
# EAST MIDLANDS             0
# WEST MIDLANDS             0
# EAST OF ENGLAND           0
# LONDON                    0
# SOUTH EAST                0
# SOUTH WEST                0
# Unnamed: 47             302
# England                   0
# dtype: int64

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties.index
# Out:
# RangeIndex(start=0, stop=302, step=1)

# %%
properties.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties = properties.transpose()

# %%
properties.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# City of London                  84409.1              94900.5
# Barking & Dagenham              53042.2              53700.3
# Barnet                            90258              90107.2
# Bexley                          63997.1              64252.3
#
#                                     7                    8    \
# Unnamed: 0          1995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                   110128               112329
# Barking & Dagenham              52113.1              52232.2
# Barnet                          91441.2              92361.3
# Bexley                          63722.7              64432.6
#
#                                     9    ...                  292  \
# Unnamed: 0          1995-09-01 00:00:00  ...  2019-04-01 00:00:00
# City of London                   104473  ...               738842
# Barking & Dagenham              51471.6  ...               296360
# Barnet                          93273.1  ...               512588
# Bexley                          64509.5  ...               339948
#
#                                     293                  294  \
# Unnamed: 0          2019-05-01 00:00:00  2019-06-01 00:00:00
# City of London                   718773               743157
# Barking & Dagenham               296555               295600
# Barnet                           503721               511926
# Bexley                           337445               339964
#
#                                     295                  296  \
# Unnamed: 0          2019-07-01 00:00:00  2019-08-01 00:00:00
# City of London                   719871               777613
# Barking & Dagenham               299538               300702
# Barnet                           514134               527996
# Bexley                           338721               338702
#
#                                     297                  298  \
# Unnamed: 0          2019-09-01 00:00:00  2019-10-01 00:00:00
# City of London                   792034               827093
# Barking & Dagenham               305277               304153
# Barnet                           527115               525739
# Bexley                           334826               334510
#
#                                     299                  300  \
# Unnamed: 0          2019-11-01 00:00:00  2019-12-01 00:00:00
# City of London                   777610               734872
# Barking & Dagenham               305882               301816
# Barnet                           523582               517986
# Bexley                           334711               336972
#
#                                     301
# Unnamed: 0          2020-01-01 00:00:00
# City of London                   775309
# Barking & Dagenham               301057
# Barnet                           520682
# Bexley                           331683
#
# [5 rows x 302 columns]

# %%
properties.reset_index()
# Out:
#                    index          0                    1                    2  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001                91449              82202.8
# 2     Barking & Dagenham  E09000002              50460.2              51085.8
# 3                 Barnet  E09000003              93284.5              93190.2
# 4                 Bexley  E09000004              64958.1              64787.9
# 5                  Brent  E09000005              71306.6              72022.3
# 6                Bromley  E09000006              81671.5              81657.6
# 7                 Camden  E09000007               120933               119509
# 8                Croydon  E09000008              69158.2              68951.1
# 9                 Ealing  E09000009              79885.9              80897.1
# 10               Enfield  E09000010              72514.7              73155.2
# 11             Greenwich  E09000011              62300.1              60993.3
# 12               Hackney  E09000012              61296.5              63187.1
# 13  Hammersmith & Fulham  E09000013               124903               122088
# 14              Haringey  E09000014              76287.6              78901.2
# 15                Harrow  E09000015              84769.5              83396.1
# 16              Havering  E09000016              68000.1              69393.5
# 17            Hillingdon  E09000017              73834.8              75031.1
# 18              Hounslow  E09000018              72231.7              71051.6
# 19             Islington  E09000019              92516.5              94342.4
# 20  Kensington & Chelsea  E09000020               182695               182345
# 21  Kingston upon Thames  E09000021              80875.8              81230.1
# 22               Lambeth  E09000022                67771              65381.5
# 23              Lewisham  E09000023              60491.3              60869.3
# 24                Merton  E09000024              82070.6              79982.7
# 25                Newham  E09000025              53539.3              53153.9
# 26             Redbridge  E09000026              72189.6              72141.6
# 27  Richmond upon Thames  E09000027               109326               111103
# 28             Southwark  E09000028              67885.2              64799.1
# 29                Sutton  E09000029                71537              70893.2
# 30         Tower Hamlets  E09000030              59865.2              62318.5
# 31        Waltham Forest  E09000031              61319.4              60252.1
# 32            Wandsworth  E09000032                88559                88641
# 33           Westminster  E09000033               133025               131468
# 34           Unnamed: 34        NaN                  NaN                  NaN
# 35          Inner London  E13000001                78252              75885.7
# 36          Outer London  E13000002              72958.8              72937.9
# 37           Unnamed: 37        NaN                  NaN                  NaN
# 38            NORTH EAST  E12000001              42076.4                42572
# 39            NORTH WEST  E12000002              43958.5              43925.4
# 40    YORKS & THE HUMBER  E12000003              44803.4              44528.8
# 41         EAST MIDLANDS  E12000004              45544.5              46051.6
# 42         WEST MIDLANDS  E12000005              48527.5              49341.3
# 43       EAST OF ENGLAND  E12000006              56701.6              56593.6
# 44                LONDON  E12000007              74435.8              72777.9
# 45            SOUTH EAST  E12000008              64018.9                63715
# 46            SOUTH WEST  E12000009              54705.2              54356.1
# 47           Unnamed: 47        NaN                  NaN                  NaN
# 48               England  E92000001              53202.8              53096.2
#
#                       3                    4                    5  \
# 0   1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1               79120.7              77101.2              84409.1
# 2                 51269              53133.5              53042.2
# 3               92247.5              90762.9                90258
# 4               64367.5              64277.7              63997.1
# 5               72015.8              72965.6                73704
# 6               81449.3              81124.4              81542.6
# 7                120282               120098               119929
# 8               68712.4                68610              68844.9
# 9               81379.9              82188.9              82077.1
# 10              72190.4              71442.9              70630.8
# 11              61377.8              61927.7                63513
# 12              63593.3              65139.6                66194
# 13               120636               121425               124434
# 14              78521.9              79545.6                79374
# 15              83416.2              83567.9              83853.7
# 16                69368              69444.3              68534.5
# 17              74188.7              73911.4              73117.1
# 18                72098              71890.3              72877.5
# 19              93465.9              93344.5              94346.4
# 20               182879               184177               191474
# 21              81111.5              81672.8              82123.5
# 22              66336.5              66388.8              69035.1
# 23                60288                59471              58551.4
# 24              80661.7              79990.5                80874
# 25              53458.3              54479.8                55804
# 26              72501.4              72228.6              72366.6
# 27               107325               106875               107708
# 28              65763.3              63073.6              64420.5
# 29              70306.8              69411.9              69759.2
# 30              63938.7              66233.2              66432.9
# 31              60871.1              60971.4              61494.2
# 32              87124.8                87026              86518.1
# 33               132260               133370               133911
# 34                  NaN                  NaN                  NaN
# 35              76591.6              76851.6              79129.2
# 36              72714.5              72591.9                72753
# 37                  NaN                  NaN                  NaN
# 38              42369.7              42095.8              43266.5
# 39              44434.9              44267.8              44223.6
# 40              45200.5              45614.3                44831
# 41              45383.8              46124.2                45878
# 42              49442.2              49455.9              50369.7
# 43              56171.2              56567.9              56479.8
# 44              73896.8              74455.3                75432
# 45              64113.6              64623.2              64530.4
# 46              53583.1                54786              54698.8
# 47                  NaN                  NaN                  NaN
# 48              53201.3              53590.9              53678.2
#
#                       6                    7                    8  ...  \
# 0   1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1               94900.5               110128               112329  ...
# 2               53700.3              52113.1              52232.2  ...
# 3               90107.2              91441.2              92361.3  ...
# 4               64252.3              63722.7              64432.6  ...
# 5               74310.5                74127                73547  ...
# 6               82382.8              82898.5              82054.4  ...
# 7                121887               124028               125530  ...
# 8               69052.5              69142.5              68993.4  ...
# 9               81630.7              82352.2              82706.7  ...
# 10              71348.3              71837.5              72237.9  ...
# 11              64751.6              65486.3              65076.4  ...
# 12              66921.2              68390.8              68096.8  ...
# 13               126175               124382               123625  ...
# 14              79956.4              80746.3              81217.7  ...
# 15              84173.2              84226.7              84430.6  ...
# 16              68464.6              68680.8              69023.4  ...
# 17                74005              74671.1              74967.9  ...
# 18              72331.1              73717.8              74479.9  ...
# 19              97428.9              98976.1              98951.2  ...
# 20               197266               197963               198037  ...
# 21              82205.7              82525.8              83342.8  ...
# 22              68881.2              69608.7                68840  ...
# 23              58041.4              58126.4              58151.3  ...
# 24              80704.9              81055.9              80781.1  ...
# 25              56067.8              55458.3              54709.4  ...
# 26              72279.4              72880.8              73275.2  ...
# 27               112865               114657               112320  ...
# 28              64155.8              67024.7              65525.9  ...
# 29              70125.2              70789.6              69958.4  ...
# 30              66232.2              64692.2              63472.3  ...
# 31              61547.8              61933.5              61916.4  ...
# 32              88114.3              89830.6              90560.7  ...
# 33               134562               133450               136582  ...
# 34                  NaN                  NaN                  NaN  ...
# 35              79969.2              80550.5              80597.6  ...
# 36              73189.4              73665.9              73691.1  ...
# 37                  NaN                  NaN                  NaN  ...
# 38              42315.3              43287.7              41899.1  ...
# 39                44113              44109.6              44193.7  ...
# 40              45392.6                45535              45111.5  ...
# 41                45680              46037.7              45922.5  ...
# 42              50100.4                49860              49598.5  ...
# 43              56288.9              57242.3              56732.4  ...
# 44              75606.2              75984.2              75529.3  ...
# 45                65511              65224.9              64851.6  ...
# 46              54420.2              54265.9              54365.7  ...
# 47                  NaN                  NaN                  NaN  ...
# 48              53735.2              53900.6              53600.3  ...
#
#                     292                  293                  294  \
# 0   2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00
# 1                738842               718773               743157
# 2                296360               296555               295600
# 3                512588               503721               511926
# 4                339948               337445               339964
# 5                487049               482244               472702
# 6                432875               430231               432035
# 7                822533               836880               871354
# 8                364013               364371               363161
# 9                461320               465025               472063
# 10               393997               388337               391342
# 11               382294               381143               388062
# 12               572994               563073               549879
# 13               713365               713548               712179
# 14               530148               542321               541576
# 15               446304               443200               448131
# 16               358877               360927               365296
# 17               405309               401452               395374
# 18               395993               398862               401748
# 19               619883               623358               627183
# 20          1.26656e+06          1.23735e+06          1.29411e+06
# 21               474617               473282               483930
# 22               499905               495063               502091
# 23               402204               405653               405553
# 24               501814               487425               499425
# 25               368035               370155               358981
# 26               403196               402650               411017
# 27               641418               637519               651995
# 28               486643               496635               494468
# 29               368717               370330               372902
# 30               432566               427827               428141
# 31               432420               425770               422441
# 32               578421               579743               576629
# 33               992834          1.02082e+06               997393
# 34                  NaN                  NaN                  NaN
# 35               563545               565648               565308
# 36               418651               416468               419626
# 37                  NaN                  NaN                  NaN
# 38               129094               128846               129606
# 39               162455               164148               163828
# 40               162101               162401               163631
# 41               191721               192243               192192
# 42               195789               197479               196812
# 43               288556               289326               289237
# 44               470092               463976               471053
# 45               319712               319201               321244
# 46               253438               252174               253334
# 47                  NaN                  NaN                  NaN
# 48               245077               245255               246140
#
#                     295                  296                  297  \
# 0   2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00
# 1                719871               777613               792034
# 2                299538               300702               305277
# 3                514134               527996               527115
# 4                338721               338702               334826
# 5                470872               486068               500246
# 6                435329               442452               440620
# 7                881212               855721               828560
# 8                365262               363885               364997
# 9                473089               473808               475064
# 10               387867               393602               386682
# 11               396728               396339               398331
# 12               558792               570665               575846
# 13               722627               729313               733133
# 14               553882               546952               556375
# 15               445549               449306               451900
# 16               367266               367402               366415
# 17               398057               396258               404082
# 18               398001               402410               406757
# 19               632614               649329               656948
# 20          1.28894e+06          1.26226e+06          1.24638e+06
# 21               502723               507183               504567
# 22               508360               519475               521142
# 23               410073               415558               420718
# 24               505198               518932               517023
# 25               356312               358034               368382
# 26               417693               424286               414820
# 27               656390               657558               648451
# 28               498785               496228               506787
# 29               374130               369204               373890
# 30               432142               442846               448436
# 31               418695               426489               431498
# 32               586165               593268               605360
# 33               957897               914870               925955
# 34                  NaN                  NaN                  NaN
# 35               569119               571661               577852
# 36               421871               425249               425650
# 37                  NaN                  NaN                  NaN
# 38               129737               131693               131941
# 39               165940               167430               166804
# 40               165047               165704               165362
# 41               193677               195129               195107
# 42               197999               201098               201029
# 43               291491               291192               292645
# 44               478348               473390               477727
# 45               322834               323011               324501
# 46               258379               258317               259145
# 47                  NaN                  NaN                  NaN
# 48               248562               249432               249942
#
#                     298                  299                  300  \
# 0   2019-10-01 00:00:00  2019-11-01 00:00:00  2019-12-01 00:00:00
# 1                827093               777610               734872
# 2                304153               305882               301816
# 3                525739               523582               517986
# 4                334510               334711               336972
# 5                494527               431249               431245
# 6                439782               438792               443391
# 7                799950               818880               807466
# 8                364424               367458               369301
# 9                478329               475304               470862
# 10               393802               393860               401981
# 11               394952               397157               398530
# 12               569477               562039               556680
# 13               720882               718071               725991
# 14               554542               561283               568238
# 15               454211               451076               450022
# 16               367546               366351               366567
# 17               403438               408048               407357
# 18               413672               410452               413137
# 19               645971               629164               645161
# 20          1.19121e+06          1.19334e+06          1.22161e+06
# 21               487844               490852               491386
# 22               516985               519234               518618
# 23               422711               417318               415125
# 24               510901               504065               505373
# 25               371678               365400               363493
# 26               411851               413867               423442
# 27               643937               649756               656781
# 28               513550               512367               505619
# 29               370475               375450               374700
# 30               455091               453177               457893
# 31               434610               435963               439009
# 32               599182               600835               604056
# 33               927864               955615               968404
# 34                  NaN                  NaN                  NaN
# 35               575198               574539               575511
# 36               424913               423302               424774
# 37                  NaN                  NaN                  NaN
# 38               129324               129646               129959
# 39               166784               165921               167285
# 40               166669               164530               166932
# 41               194961               195515               196534
# 42               200388               201447               199814
# 43               291566               289917               293497
# 44               474318               469422               481710
# 45               323581               323951               324515
# 46               259092               257363               259011
# 47                  NaN                  NaN                  NaN
# 48               249376               248515               250410
#
#                     301
# 0   2020-01-01 00:00:00
# 1                775309
# 2                301057
# 3                520682
# 4                331683
# 5                408523
# 6                436757
# 7                810298
# 8                368662
# 9                473268
# 10               391365
# 11               392699
# 12               571882
# 13               749337
# 14               578728
# 15               460121
# 16               359188
# 17               413229
# 18               412352
# 19               673418
# 20          1.17817e+06
# 21               483250
# 22               526690
# 23               412522
# 24               507897
# 25               368816
# 26               418360
# 27               675114
# 28               502612
# 29               371626
# 30               450669
# 31               452299
# 32               610256
# 33          1.01903e+06
# 34                  NaN
# 35               581939
# 36               423006
# 37                  NaN
# 38               126592
# 39               164769
# 40               165383
# 41               195707
# 42               200628
# 43               286999
# 44               476588
# 45               320700
# 46               254320
# 47                  NaN
# 48               247355
#
# [49 rows x 303 columns]

# %%
 # Dropping city of london , not a part of 32 london boroughs
properties = properties.drop(properties.index[1])

# %%
# Dropping index 34 to 49,  also not part of 32 london boroughs
properties = properties.drop(properties.index[33:])

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties = properties.reset_index()

# %%
# Renaming of Columns
properties.iloc[0,0] = 'Boroughs'
properties.iloc[0,1] = 'ID'

# %%
properties.head()
# Out:
#                 index          0                    1                    2  \
# 0            Boroughs         ID  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1  Barking & Dagenham  E09000002              50460.2              51085.8
# 2              Barnet  E09000003              93284.5              93190.2
# 3              Bexley  E09000004              64958.1              64787.9
# 4               Brent  E09000005              71306.6              72022.3
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1                51269              53133.5              53042.2
# 2              92247.5              90762.9                90258
# 3              64367.5              64277.7              63997.1
# 4              72015.8              72965.6                73704
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              53700.3              52113.1              52232.2  ...
# 2              90107.2              91441.2              92361.3  ...
# 3              64252.3              63722.7              64432.6  ...
# 4              74310.5                74127                73547  ...
#
#                    292                  293                  294  \
# 0  2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00
# 1               296360               296555               295600
# 2               512588               503721               511926
# 3               339948               337445               339964
# 4               487049               482244               472702
#
#                    295                  296                  297  \
# 0  2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00
# 1               299538               300702               305277
# 2               514134               527996               527115
# 3               338721               338702               334826
# 4               470872               486068               500246
#
#                    298                  299                  300  \
# 0  2019-10-01 00:00:00  2019-11-01 00:00:00  2019-12-01 00:00:00
# 1               304153               305882               301816
# 2               525739               523582               517986
# 3               334510               334711               336972
# 4               494527               431249               431245
#
#                    301
# 0  2020-01-01 00:00:00
# 1               301057
# 2               520682
# 3               331683
# 4               408523
#
# [5 rows x 303 columns]

# %%
# truncating timestamp of columns to display YYYY-mm 1995-01

for i in range (2, len(properties.iloc[0])):
    properties.iloc[0, i] = str(properties.iloc[0,i])[:-12]

# %%
#set column header : setting first row as header
new_header = properties.iloc[0]
properties = properties.iloc[1:]
properties.columns = new_header

# %%
properties
# Out:
# 0               Boroughs         ID  1995-01  1995-02  1995-03  1995-04  \
# 1     Barking & Dagenham  E09000002  50460.2  51085.8    51269  53133.5
# 2                 Barnet  E09000003  93284.5  93190.2  92247.5  90762.9
# 3                 Bexley  E09000004  64958.1  64787.9  64367.5  64277.7
# 4                  Brent  E09000005  71306.6  72022.3  72015.8  72965.6
# 5                Bromley  E09000006  81671.5  81657.6  81449.3  81124.4
# 6                 Camden  E09000007   120933   119509   120282   120098
# 7                Croydon  E09000008  69158.2  68951.1  68712.4    68610
# 8                 Ealing  E09000009  79885.9  80897.1  81379.9  82188.9
# 9                Enfield  E09000010  72514.7  73155.2  72190.4  71442.9
# 10             Greenwich  E09000011  62300.1  60993.3  61377.8  61927.7
# 11               Hackney  E09000012  61296.5  63187.1  63593.3  65139.6
# 12  Hammersmith & Fulham  E09000013   124903   122088   120636   121425
# 13              Haringey  E09000014  76287.6  78901.2  78521.9  79545.6
# 14                Harrow  E09000015  84769.5  83396.1  83416.2  83567.9
# 15              Havering  E09000016  68000.1  69393.5    69368  69444.3
# 16            Hillingdon  E09000017  73834.8  75031.1  74188.7  73911.4
# 17              Hounslow  E09000018  72231.7  71051.6    72098  71890.3
# 18             Islington  E09000019  92516.5  94342.4  93465.9  93344.5
# 19  Kensington & Chelsea  E09000020   182695   182345   182879   184177
# 20  Kingston upon Thames  E09000021  80875.8  81230.1  81111.5  81672.8
# 21               Lambeth  E09000022    67771  65381.5  66336.5  66388.8
# 22              Lewisham  E09000023  60491.3  60869.3    60288    59471
# 23                Merton  E09000024  82070.6  79982.7  80661.7  79990.5
# 24                Newham  E09000025  53539.3  53153.9  53458.3  54479.8
# 25             Redbridge  E09000026  72189.6  72141.6  72501.4  72228.6
# 26  Richmond upon Thames  E09000027   109326   111103   107325   106875
# 27             Southwark  E09000028  67885.2  64799.1  65763.3  63073.6
# 28                Sutton  E09000029    71537  70893.2  70306.8  69411.9
# 29         Tower Hamlets  E09000030  59865.2  62318.5  63938.7  66233.2
# 30        Waltham Forest  E09000031  61319.4  60252.1  60871.1  60971.4
# 31            Wandsworth  E09000032    88559    88641  87124.8    87026
# 32           Westminster  E09000033   133025   131468   132260   133370
#
# 0   1995-05  1995-06  1995-07  1995-08  ...      2019-04      2019-05  \
# 1   53042.2  53700.3  52113.1  52232.2  ...       296360       296555
# 2     90258  90107.2  91441.2  92361.3  ...       512588       503721
# 3   63997.1  64252.3  63722.7  64432.6  ...       339948       337445
# 4     73704  74310.5    74127    73547  ...       487049       482244
# 5   81542.6  82382.8  82898.5  82054.4  ...       432875       430231
# 6    119929   121887   124028   125530  ...       822533       836880
# 7   68844.9  69052.5  69142.5  68993.4  ...       364013       364371
# 8   82077.1  81630.7  82352.2  82706.7  ...       461320       465025
# 9   70630.8  71348.3  71837.5  72237.9  ...       393997       388337
# 10    63513  64751.6  65486.3  65076.4  ...       382294       381143
# 11    66194  66921.2  68390.8  68096.8  ...       572994       563073
# 12   124434   126175   124382   123625  ...       713365       713548
# 13    79374  79956.4  80746.3  81217.7  ...       530148       542321
# 14  83853.7  84173.2  84226.7  84430.6  ...       446304       443200
# 15  68534.5  68464.6  68680.8  69023.4  ...       358877       360927
# 16  73117.1    74005  74671.1  74967.9  ...       405309       401452
# 17  72877.5  72331.1  73717.8  74479.9  ...       395993       398862
# 18  94346.4  97428.9  98976.1  98951.2  ...       619883       623358
# 19   191474   197266   197963   198037  ...  1.26656e+06  1.23735e+06
# 20  82123.5  82205.7  82525.8  83342.8  ...       474617       473282
# 21  69035.1  68881.2  69608.7    68840  ...       499905       495063
# 22  58551.4  58041.4  58126.4  58151.3  ...       402204       405653
# 23    80874  80704.9  81055.9  80781.1  ...       501814       487425
# 24    55804  56067.8  55458.3  54709.4  ...       368035       370155
# 25  72366.6  72279.4  72880.8  73275.2  ...       403196       402650
# 26   107708   112865   114657   112320  ...       641418       637519
# 27  64420.5  64155.8  67024.7  65525.9  ...       486643       496635
# 28  69759.2  70125.2  70789.6  69958.4  ...       368717       370330
# 29  66432.9  66232.2  64692.2  63472.3  ...       432566       427827
# 30  61494.2  61547.8  61933.5  61916.4  ...       432420       425770
# 31  86518.1  88114.3  89830.6  90560.7  ...       578421       579743
# 32   133911   134562   133450   136582  ...       992834  1.02082e+06
#
# 0       2019-06      2019-07      2019-08      2019-09      2019-10  \
# 1        295600       299538       300702       305277       304153
# 2        511926       514134       527996       527115       525739
# 3        339964       338721       338702       334826       334510
# 4        472702       470872       486068       500246       494527
# 5        432035       435329       442452       440620       439782
# 6        871354       881212       855721       828560       799950
# 7        363161       365262       363885       364997       364424
# 8        472063       473089       473808       475064       478329
# 9        391342       387867       393602       386682       393802
# 10       388062       396728       396339       398331       394952
# 11       549879       558792       570665       575846       569477
# 12       712179       722627       729313       733133       720882
# 13       541576       553882       546952       556375       554542
# 14       448131       445549       449306       451900       454211
# 15       365296       367266       367402       366415       367546
# 16       395374       398057       396258       404082       403438
# 17       401748       398001       402410       406757       413672
# 18       627183       632614       649329       656948       645971
# 19  1.29411e+06  1.28894e+06  1.26226e+06  1.24638e+06  1.19121e+06
# 20       483930       502723       507183       504567       487844
# 21       502091       508360       519475       521142       516985
# 22       405553       410073       415558       420718       422711
# 23       499425       505198       518932       517023       510901
# 24       358981       356312       358034       368382       371678
# 25       411017       417693       424286       414820       411851
# 26       651995       656390       657558       648451       643937
# 27       494468       498785       496228       506787       513550
# 28       372902       374130       369204       373890       370475
# 29       428141       432142       442846       448436       455091
# 30       422441       418695       426489       431498       434610
# 31       576629       586165       593268       605360       599182
# 32       997393       957897       914870       925955       927864
#
# 0       2019-11      2019-12      2020-01
# 1        305882       301816       301057
# 2        523582       517986       520682
# 3        334711       336972       331683
# 4        431249       431245       408523
# 5        438792       443391       436757
# 6        818880       807466       810298
# 7        367458       369301       368662
# 8        475304       470862       473268
# 9        393860       401981       391365
# 10       397157       398530       392699
# 11       562039       556680       571882
# 12       718071       725991       749337
# 13       561283       568238       578728
# 14       451076       450022       460121
# 15       366351       366567       359188
# 16       408048       407357       413229
# 17       410452       413137       412352
# 18       629164       645161       673418
# 19  1.19334e+06  1.22161e+06  1.17817e+06
# 20       490852       491386       483250
# 21       519234       518618       526690
# 22       417318       415125       412522
# 23       504065       505373       507897
# 24       365400       363493       368816
# 25       413867       423442       418360
# 26       649756       656781       675114
# 27       512367       505619       502612
# 28       375450       374700       371626
# 29       453177       457893       450669
# 30       435963       439009       452299
# 31       600835       604056       610256
# 32       955615       968404  1.01903e+06
#
# [32 rows x 303 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties = pd.melt(properties, id_vars=['ID','Boroughs'])

# %%
properties.set_index('ID')
# Out:
#                      Boroughs        0        value
# ID
# E09000002  Barking & Dagenham  1995-01      50460.2
# E09000003              Barnet  1995-01      93284.5
# E09000004              Bexley  1995-01      64958.1
# E09000005               Brent  1995-01      71306.6
# E09000006             Bromley  1995-01      81671.5
# ...                       ...      ...          ...
# E09000029              Sutton  2020-01       371626
# E09000030       Tower Hamlets  2020-01       450669
# E09000031      Waltham Forest  2020-01       452299
# E09000032          Wandsworth  2020-01       610256
# E09000033         Westminster  2020-01  1.01903e+06
#
# [9632 rows x 3 columns]

# %%
properties = properties.rename(columns={'value':'Price', 0:'Date'})

# %%
properties['Date']
# Out:
# 0       1995-01
# 1       1995-01
# 2       1995-01
# 3       1995-01
# 4       1995-01
#          ...
# 9627    2020-01
# 9628    2020-01
# 9629    2020-01
# 9630    2020-01
# 9631    2020-01
# Name: Date, Length: 9632, dtype: object

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#extracting year and month from TimeStamp data
year = []
month = []
for i in range (len(properties['Date'])):
    
    year.append(str(properties['Date'][i])[:-15])
    month.append(str(properties['Date'][i])[5:-12])
properties['Year'] = year
properties['Month'] = month

# %%
#convert datatypes to string, datetime
properties['Boroughs'] = properties['Boroughs'].astype('category')
properties['Date'] = pd.to_datetime(properties['Date'])
properties['Price'] = pd.to_numeric(properties['Price'])
properties['Year'] = pd.to_numeric(properties['Year'])
properties['Month'] = pd.to_numeric(properties['Month'])

# Round off Price to 2 decimals
properties['Price'] = round(properties['Price'],2)

# %%
properties
# Out:
#              ID            Boroughs       Date       Price  Year  Month
# 0     E09000002  Barking & Dagenham 1995-01-01    50460.23  1995      1
# 1     E09000003              Barnet 1995-01-01    93284.52  1995      1
# 2     E09000004              Bexley 1995-01-01    64958.09  1995      1
# 3     E09000005               Brent 1995-01-01    71306.57  1995      1
# 4     E09000006             Bromley 1995-01-01    81671.48  1995      1
# ...         ...                 ...        ...         ...   ...    ...
# 9627  E09000029              Sutton 2020-01-01   371625.70  2020      1
# 9628  E09000030       Tower Hamlets 2020-01-01   450668.76  2020      1
# 9629  E09000031      Waltham Forest 2020-01-01   452298.92  2020      1
# 9630  E09000032          Wandsworth 2020-01-01   610255.99  2020      1
# 9631  E09000033         Westminster 2020-01-01  1019028.25  2020      1
#
# [9632 rows x 6 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
new_properties = properties[['ID', 'Boroughs', 'Year', 'Price']]

# %%
# list of 32 boroughs are stored in bor
bor = new_properties['Boroughs'].unique()

# %%
bor
# Out:
# [Barking & Dagenham, Barnet, Bexley, Brent, Bromley, ..., Sutton, Tower Hamlets, Waltham Forest, Wandsworth, Westminster]
# Length: 32
# Categories (32, object): [Barking & Dagenham, Barnet, Bexley, Brent, ..., Tower Hamlets, Waltham Forest, Wandsworth, Westminster]

# %%
#function to calculate ratio of average prices of boroughs of 1995 and 2019 for each borough
def bor_ratio(i):
    lon_bor = new_properties[new_properties['Boroughs']== bor[i]]
    lon_bor = lon_bor.groupby('Year')['Price'].mean()
    lon_bor = round(lon_bor,2)
    bor95 = lon_bor[lon_bor.index == 1995]
    bor19 = lon_bor[lon_bor.index == 2019]
    avgbor = bor95.values/(bor19.values)*100
    return avgbor

# %%
#assigning the ratios of each borough by running the function bor_ratio()
avgbd = bor_ratio(0)
avgbar = bor_ratio(1)
avgbex = bor_ratio(2)
avgbre = bor_ratio(3)
avgbro = bor_ratio(4)
avgcam = bor_ratio(5)
avgcro = bor_ratio(6)
avgeal = bor_ratio(7)
avgenf = bor_ratio(8)
avggre = bor_ratio(9)
avghac = bor_ratio(10)
avgham = bor_ratio(11)
avghar = bor_ratio(12)
avgharr = bor_ratio(13)
avghav = bor_ratio(14)
avghil = bor_ratio(15)
avghou = bor_ratio(16)
avgisl = bor_ratio(17)
avgken = bor_ratio(18)
avgkut = bor_ratio(19)
avglam = bor_ratio(20)
avglew = bor_ratio(21)
avgmer = bor_ratio(22)
avgnew = bor_ratio(23)
avgred = bor_ratio(24)
avgrut = bor_ratio(25)
avgsou = bor_ratio(26)
avgsut = bor_ratio(27)
avgtow = bor_ratio(28)
avgfor = bor_ratio(29)
avgwan = bor_ratio(30)
avgwes = bor_ratio(31)

# %%
# average values of all 32 London Boroughs are stored in a list called avg
avg = [avgbd, avgbar, avgbex, avgbre,avgbro, avgcam, avgcro,avgeal, avgenf, avggre, avghac, avgham, avghar, avgharr, 
       avghav,avghil, avghou,avgisl,avgken,avgkut,avglam, avglew, avgmer, avgnew, avgred, avgrut, avgsou, avgsut,avgtow,
       avgfor, avgwan,avgwes]
for i in range(len(bor)):
    print('The Ratio of Average Prices between 1995 and 2019 of %s is %f' % (bor[i], avg[i]))
# Out:
# The Ratio of Average Prices between 1995 and 2019 of Barking & Dagenham is 17.313401
# The Ratio of Average Prices between 1995 and 2019 of Barnet is 17.667612
# The Ratio of Average Prices between 1995 and 2019 of Bexley is 19.047237
# The Ratio of Average Prices between 1995 and 2019 of Brent is 15.401552
# The Ratio of Average Prices between 1995 and 2019 of Bromley is 18.726810
# The Ratio of Average Prices between 1995 and 2019 of Camden is 14.354526
# The Ratio of Average Prices between 1995 and 2019 of Croydon is 18.864972
# The Ratio of Average Prices between 1995 and 2019 of Ealing is 17.185447
# The Ratio of Average Prices between 1995 and 2019 of Enfield is 18.307941
# The Ratio of Average Prices between 1995 and 2019 of Greenwich is 16.194205
# The Ratio of Average Prices between 1995 and 2019 of Hackney is 11.832158
# The Ratio of Average Prices between 1995 and 2019 of Hammersmith & Fulham is 17.100983
# The Ratio of Average Prices between 1995 and 2019 of Haringey is 14.594569
# The Ratio of Average Prices between 1995 and 2019 of Harrow is 18.585882
# The Ratio of Average Prices between 1995 and 2019 of Havering is 18.716249
# The Ratio of Average Prices between 1995 and 2019 of Hillingdon is 18.220988
# The Ratio of Average Prices between 1995 and 2019 of Hounslow is 18.151276
# The Ratio of Average Prices between 1995 and 2019 of Islington is 15.048826
# The Ratio of Average Prices between 1995 and 2019 of Kensington & Chelsea is 15.464154
# The Ratio of Average Prices between 1995 and 2019 of Kingston upon Thames is 16.996461
# The Ratio of Average Prices between 1995 and 2019 of Lambeth is 13.402705
# The Ratio of Average Prices between 1995 and 2019 of Lewisham is 14.368727
# The Ratio of Average Prices between 1995 and 2019 of Merton is 15.866726
# The Ratio of Average Prices between 1995 and 2019 of Newham is 14.989941
# The Ratio of Average Prices between 1995 and 2019 of Redbridge is 17.556446
# The Ratio of Average Prices between 1995 and 2019 of Richmond upon Thames is 16.897623
# The Ratio of Average Prices between 1995 and 2019 of Southwark is 12.872804
# The Ratio of Average Prices between 1995 and 2019 of Sutton is 18.870093
# The Ratio of Average Prices between 1995 and 2019 of Tower Hamlets is 14.499104
# The Ratio of Average Prices between 1995 and 2019 of Waltham Forest is 14.229199
# The Ratio of Average Prices between 1995 and 2019 of Wandsworth is 15.089729
# The Ratio of Average Prices between 1995 and 2019 of Westminster is 13.950608

# %%
#bar plotting of ratio of each borrough
fig, ax= plt.subplots(sharey=True)
ax.bar(bor[0], avgbd)
ax.bar(bor[1], avgbar)
ax.bar(bor[2], avgbex)
ax.bar(bor[3], avgbre)
ax.bar(bor[4], avgbro)
ax.bar(bor[5], avgcam)
ax.bar(bor[6], avgcro)
ax.bar(bor[7], avgeal)
ax.bar(bor[8], avgenf)
ax.bar(bor[9], avggre)
ax.bar(bor[10], avghac)
ax.bar(bor[11], avgham)
ax.bar(bor[12], avghar)
ax.bar(bor[13], avgharr)
ax.bar(bor[14], avghav)
ax.bar(bor[15], avghil)
ax.bar(bor[16], avghou)
ax.bar(bor[17], avgisl)
ax.bar(bor[18], avgken)
ax.bar(bor[19], avgkut)
ax.bar(bor[20], avglam)
ax.bar(bor[21], avglew)
ax.bar(bor[22], avgmer)
ax.bar(bor[23], avgnew)
ax.bar(bor[24], avgred)
ax.bar(bor[25], avgrut)
ax.bar(bor[26], avgsou)
ax.bar(bor[27], avgsut)
ax.bar(bor[28], avgtow)
ax.bar(bor[29], avgfor)
ax.bar(bor[30], avgwan)
ax.bar(bor[31], avgwes)
ax.set_xlabel('London Boroughs')
ax.set_ylabel('Ratio of Average Prices of 1995 and 2019')
ax.set_title('London Real Estate')
plt.ylim(10,20)
ax.set_xticklabels(bor.categories, rotation=90)
plt.savefig('ratio_london.png')
plt.show()

# %%
# function to return the average prices of all boroughs year-wise from 1995 to 2020
def bor_avg(i):
    lon_bor = new_properties[new_properties['Boroughs']== bor[i]]
    lon_bor = lon_bor.groupby('Year')['Price'].mean()
    lon_bor = round(lon_bor,2)
    return lon_bor

# %%
#assigning the average prices of each borough by executing the function bor_avg()
bor_bd = bor_avg(0)
bor_barnet = bor_avg(1)
bor_bexley = bor_avg(2)
bor_brent = bor_avg(3)
bor_bromley = bor_avg(4)
bor_camden = bor_avg(5)
bor_Croydon = bor_avg(6)
bor_Ealing = bor_avg(7)
bor_Enfield = bor_avg(8)
bor_Greenwich = bor_avg(9)
bor_Hackney = bor_avg(10)
bor_hamful = bor_avg(11)
bor_Haringey = bor_avg(12)
bor_Harrow = bor_avg(13)
bor_Havering = bor_avg(14)
bor_Hillingdon = bor_avg(15)
bor_Hounslow =  bor_avg(16)
bor_Islington = bor_avg(17)
bor_kenche =  bor_avg(18)
bor_kut = bor_avg(19)
bor_lam = bor_avg(20)
bor_Lewisham = bor_avg(21)
bor_Merton = bor_avg(22)
bor_Newham = bor_avg(23)
bor_Redbridge = bor_avg(24)
bor_rut = bor_avg(25)
bor_Southwark = bor_avg(26)
bor_sut = bor_avg(27)
bor_tow = bor_avg(28)
bor_forest = bor_avg(29)
bor_wands = bor_avg(30)
bor_west = bor_avg(31)

# %%
#line plot of each individual boroughs
fig, ax= plt.subplots(sharey=True)
ax.plot(bor_bd, marker='o', color ='black')
ax.plot(bor_barnet, marker='v')
ax.plot(bor_bexley, linestyle='--')
ax.plot(bor_brent, linestyle='--')
ax.plot(bor_bromley,linestyle='--')
ax.plot(bor_camden, marker='o', color='orange')# Camden
ax.plot(bor_Croydon)
ax.plot(bor_Ealing)
ax.plot(bor_Enfield)
ax.plot(bor_Greenwich, marker='v')
ax.plot(bor_Hackney)
ax.plot(bor_hamful)
ax.plot(bor_Haringey)
ax.plot(bor_Harrow)
ax.plot(bor_Havering, marker='v')
ax.plot(bor_Hillingdon)
ax.plot(bor_Hounslow)
ax.plot(bor_Islington)
ax.plot(bor_kenche, linestyle='--',marker='o', color='b') #Kensington & Chelsea
ax.plot(bor_kut,linestyle='--')
ax.plot(bor_lam)
ax.plot(bor_Lewisham, marker='v')
ax.plot(bor_Merton,linestyle='--')
ax.plot(bor_Newham,linestyle='--')
ax.plot(bor_Redbridge, linestyle='--')
ax.plot(bor_rut,linestyle='--')
ax.plot(bor_Southwark, linestyle='--')
ax.plot(bor_sut)
ax.plot(bor_tow)
ax.plot(bor_forest)
ax.plot(bor_wands, marker='v')
ax.plot(bor_west, marker='v',linestyle='--', color='green') # Westminster
ax.set_xlabel('Year')
ax.set_ylabel('Average Price')
ax.set_title('London Boroughs')
ax.annotate("Kensington & Chelsea",  xy=(0.95,0.85), xycoords='axes fraction', xytext=(0.2, 0.9),arrowprops={'arrowstyle': '->', 'color': 'orange'})
ax.annotate("Westminster",  xy=(0.75,0.65), xycoords='axes fraction', xytext=(0.2, 0.7),arrowprops={'arrowstyle': '->', 'color': 'orange'})
ax.annotate("Camden",  xy=(0.95,0.6), xycoords='axes fraction', xytext=(0.2, 0.6),arrowprops={'arrowstyle': '->', 'color': 'orange'})
ax.annotate("Barking & Dagenham",  xy=(0.95,0.2), xycoords='axes fraction', xytext=(0.4, 0.05),arrowprops={'arrowstyle': '->', 'color': 'orange'})
plt.savefig('properties.png')
plt.show()

# %%
new_properties.to_csv('london.csv')

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ###### There are total 32 in no. of Boroughs in London, namely Barking & Dagenham, Barnet, Bexley, Brent,Bromley, Camden, Croydon, Ealing, Enfield ,Greenwich ,Hackney, Hammersmith & Fulham, Haringey, Harrow, Havering, Hillingdon,Hounslow, Islington, Kensington & Chelsea, Kingston upon Thames, Lambeth, Lewisham, Merton, Newham, Redbridge, Richmond upon Thames, Southwark, Sutton, Tower Hamlets, Waltham Forest, Wandsworth and Westminster.
#     The most expensive borough in London (according to the rise of average prices from 1995 to 2019) is Kensington & Chelsea, followed by Westminster and Camden and the least expensive is Barking & Dagenham.

# %% [markdown]
# According to the ratio of average price of 1995 and 2019, Bexley, Sutton boroughs rank highest
