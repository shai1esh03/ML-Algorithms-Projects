# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
from datetime import datetime as dt

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %%
properties.dtypes
# Out:
# Unnamed: 0              datetime64[ns]
# City of London                  object
# Barking & Dagenham              object
# Barnet                          object
# Bexley                          object
# Brent                           object
# Bromley                         object
# Camden                          object
# Croydon                         object
# Ealing                          object
# Enfield                         object
# Greenwich                       object
# Hackney                         object
# Hammersmith & Fulham            object
# Haringey                        object
# Harrow                          object
# Havering                        object
# Hillingdon                      object
# Hounslow                        object
# Islington                       object
# Kensington & Chelsea            object
# Kingston upon Thames            object
# Lambeth                         object
# Lewisham                        object
# Merton                          object
# Newham                          object
# Redbridge                       object
# Richmond upon Thames            object
# Southwark                       object
# Sutton                          object
# Tower Hamlets                   object
# Waltham Forest                  object
# Wandsworth                      object
# Westminster                     object
# Unnamed: 34                    float64
# Inner London                    object
# Outer London                    object
# Unnamed: 37                    float64
# NORTH EAST                      object
# NORTH WEST                      object
# YORKS & THE HUMBER              object
# EAST MIDLANDS                   object
# WEST MIDLANDS                   object
# EAST OF ENGLAND                 object
# LONDON                          object
# SOUTH EAST                      object
# SOUTH WEST                      object
# Unnamed: 47                    float64
# England                         object
# dtype: object

# %%
properties.isnull().sum()
# Out:
# Unnamed: 0                1
# City of London            0
# Barking & Dagenham        0
# Barnet                    0
# Bexley                    0
# Brent                     0
# Bromley                   0
# Camden                    0
# Croydon                   0
# Ealing                    0
# Enfield                   0
# Greenwich                 0
# Hackney                   0
# Hammersmith & Fulham      0
# Haringey                  0
# Harrow                    0
# Havering                  0
# Hillingdon                0
# Hounslow                  0
# Islington                 0
# Kensington & Chelsea      0
# Kingston upon Thames      0
# Lambeth                   0
# Lewisham                  0
# Merton                    0
# Newham                    0
# Redbridge                 0
# Richmond upon Thames      0
# Southwark                 0
# Sutton                    0
# Tower Hamlets             0
# Waltham Forest            0
# Wandsworth                0
# Westminster               0
# Unnamed: 34             306
# Inner London              0
# Outer London              0
# Unnamed: 37             306
# NORTH EAST                0
# NORTH WEST                0
# YORKS & THE HUMBER        0
# EAST MIDLANDS             0
# WEST MIDLANDS             0
# EAST OF ENGLAND           0
# LONDON                    0
# SOUTH EAST                0
# SOUTH WEST                0
# Unnamed: 47             306
# England                   0
# dtype: int64

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties.index
# Out:
# RangeIndex(start=0, stop=306, step=1)

# %%
properties.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties = properties.transpose()

# %%
properties.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# City of London                  84409.1              94900.5
# Barking & Dagenham              53042.2              53700.3
# Barnet                            90258              90107.2
# Bexley                          63997.1              64252.3
#
#                                     7                    8    \
# Unnamed: 0          1995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                   110128               112329
# Barking & Dagenham              52113.1              52232.2
# Barnet                          91441.2              92361.3
# Bexley                          63722.7              64432.6
#
#                                     9    ...                  296  \
# Unnamed: 0          1995-09-01 00:00:00  ...  2019-08-01 00:00:00
# City of London                   104473  ...               813770
# Barking & Dagenham              51471.6  ...               299421
# Barnet                          93273.1  ...               528577
# Bexley                          64509.5  ...               337523
#
#                                     297                  298  \
# Unnamed: 0          2019-09-01 00:00:00  2019-10-01 00:00:00
# City of London                   810455               826227
# Barking & Dagenham               304778               304579
# Barnet                           526670               525678
# Bexley                           333340               332920
#
#                                     299                  300  \
# Unnamed: 0          2019-11-01 00:00:00  2019-12-01 00:00:00
# City of London                   776894               737275
# Barking & Dagenham               306390               301283
# Barnet                           522639               519306
# Bexley                           333657               336302
#
#                                     301                  302  \
# Unnamed: 0          2020-01-01 00:00:00  2020-02-01 00:00:00
# City of London                   747611               777640
# Barking & Dagenham               303653               304265
# Barnet                           518542               519121
# Bexley                           334765               337760
#
#                                     303                  304  \
# Unnamed: 0          2020-03-01 00:00:00  2020-04-01 00:00:00
# City of London                   844989               867841
# Barking & Dagenham               304099               283139
# Barnet                           527747               526553
# Bexley                           339215               346840
#
#                                     305
# Unnamed: 0          2020-05-01 00:00:00
# City of London                   899831
# Barking & Dagenham               295744
# Barnet                           532503
# Bexley                           339408
#
# [5 rows x 306 columns]

# %%
properties.reset_index()
# Out:
#                    index          0                    1                    2  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001                91449              82202.8
# 2     Barking & Dagenham  E09000002              50460.2              51085.8
# 3                 Barnet  E09000003              93284.5              93190.2
# 4                 Bexley  E09000004              64958.1              64787.9
# 5                  Brent  E09000005              71306.6              72022.3
# 6                Bromley  E09000006              81671.5              81657.6
# 7                 Camden  E09000007               120933               119509
# 8                Croydon  E09000008              69158.2              68951.1
# 9                 Ealing  E09000009              79885.9              80897.1
# 10               Enfield  E09000010              72514.7              73155.2
# 11             Greenwich  E09000011              62300.1              60993.3
# 12               Hackney  E09000012              61296.5              63187.1
# 13  Hammersmith & Fulham  E09000013               124903               122088
# 14              Haringey  E09000014              76287.6              78901.2
# 15                Harrow  E09000015              84769.5              83396.1
# 16              Havering  E09000016              68000.1              69393.5
# 17            Hillingdon  E09000017              73834.8              75031.1
# 18              Hounslow  E09000018              72231.7              71051.6
# 19             Islington  E09000019              92516.5              94342.4
# 20  Kensington & Chelsea  E09000020               182695               182345
# 21  Kingston upon Thames  E09000021              80875.8              81230.1
# 22               Lambeth  E09000022                67771              65381.5
# 23              Lewisham  E09000023              60491.3              60869.3
# 24                Merton  E09000024              82070.6              79982.7
# 25                Newham  E09000025              53539.3              53153.9
# 26             Redbridge  E09000026              72189.6              72141.6
# 27  Richmond upon Thames  E09000027               109326               111103
# 28             Southwark  E09000028              67885.2              64799.1
# 29                Sutton  E09000029                71537              70893.2
# 30         Tower Hamlets  E09000030              59865.2              62318.5
# 31        Waltham Forest  E09000031              61319.4              60252.1
# 32            Wandsworth  E09000032                88559                88641
# 33           Westminster  E09000033               133025               131468
# 34           Unnamed: 34        NaN                  NaN                  NaN
# 35          Inner London  E13000001                78252              75885.7
# 36          Outer London  E13000002              72958.8              72937.9
# 37           Unnamed: 37        NaN                  NaN                  NaN
# 38            NORTH EAST  E12000001              42076.4                42572
# 39            NORTH WEST  E12000002              43958.5              43925.4
# 40    YORKS & THE HUMBER  E12000003              44803.4              44528.8
# 41         EAST MIDLANDS  E12000004              45544.5              46051.6
# 42         WEST MIDLANDS  E12000005              48527.5              49341.3
# 43       EAST OF ENGLAND  E12000006              56701.6              56593.6
# 44                LONDON  E12000007              74435.8              72777.9
# 45            SOUTH EAST  E12000008              64018.9                63715
# 46            SOUTH WEST  E12000009              54705.2              54356.1
# 47           Unnamed: 47        NaN                  NaN                  NaN
# 48               England  E92000001              53202.8              53096.2
#
#                       3                    4                    5  \
# 0   1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1               79120.7              77101.2              84409.1
# 2                 51269              53133.5              53042.2
# 3               92247.5              90762.9                90258
# 4               64367.5              64277.7              63997.1
# 5               72015.8              72965.6                73704
# 6               81449.3              81124.4              81542.6
# 7                120282               120098               119929
# 8               68712.4                68610              68844.9
# 9               81379.9              82188.9              82077.1
# 10              72190.4              71442.9              70630.8
# 11              61377.8              61927.7                63513
# 12              63593.3              65139.6                66194
# 13               120636               121425               124434
# 14              78521.9              79545.6                79374
# 15              83416.2              83567.9              83853.7
# 16                69368              69444.3              68534.5
# 17              74188.7              73911.4              73117.1
# 18                72098              71890.3              72877.5
# 19              93465.9              93344.5              94346.4
# 20               182879               184177               191474
# 21              81111.5              81672.8              82123.5
# 22              66336.5              66388.8              69035.1
# 23                60288                59471              58551.4
# 24              80661.7              79990.5                80874
# 25              53458.3              54479.8                55804
# 26              72501.4              72228.6              72366.6
# 27               107325               106875               107708
# 28              65763.3              63073.6              64420.5
# 29              70306.8              69411.9              69759.2
# 30              63938.7              66233.2              66432.9
# 31              60871.1              60971.4              61494.2
# 32              87124.8                87026              86518.1
# 33               132260               133370               133911
# 34                  NaN                  NaN                  NaN
# 35              76591.6              76851.6              79129.2
# 36              72714.5              72591.9                72753
# 37                  NaN                  NaN                  NaN
# 38              42369.7              42095.8              43266.5
# 39              44434.9              44267.8              44223.6
# 40              45200.5              45614.3                44831
# 41              45383.8              46124.2                45878
# 42              49442.2              49455.9              50369.7
# 43              56171.2              56567.9              56479.8
# 44              73896.8              74455.3                75432
# 45              64113.6              64623.2              64530.4
# 46              53583.1                54786              54698.8
# 47                  NaN                  NaN                  NaN
# 48              53201.3              53590.9              53678.2
#
#                       6                    7                    8  ...  \
# 0   1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1               94900.5               110128               112329  ...
# 2               53700.3              52113.1              52232.2  ...
# 3               90107.2              91441.2              92361.3  ...
# 4               64252.3              63722.7              64432.6  ...
# 5               74310.5                74127                73547  ...
# 6               82382.8              82898.5              82054.4  ...
# 7                121887               124028               125530  ...
# 8               69052.5              69142.5              68993.4  ...
# 9               81630.7              82352.2              82706.7  ...
# 10              71348.3              71837.5              72237.9  ...
# 11              64751.6              65486.3              65076.4  ...
# 12              66921.2              68390.8              68096.8  ...
# 13               126175               124382               123625  ...
# 14              79956.4              80746.3              81217.7  ...
# 15              84173.2              84226.7              84430.6  ...
# 16              68464.6              68680.8              69023.4  ...
# 17                74005              74671.1              74967.9  ...
# 18              72331.1              73717.8              74479.9  ...
# 19              97428.9              98976.1              98951.2  ...
# 20               197266               197963               198037  ...
# 21              82205.7              82525.8              83342.8  ...
# 22              68881.2              69608.7                68840  ...
# 23              58041.4              58126.4              58151.3  ...
# 24              80704.9              81055.9              80781.1  ...
# 25              56067.8              55458.3              54709.4  ...
# 26              72279.4              72880.8              73275.2  ...
# 27               112865               114657               112320  ...
# 28              64155.8              67024.7              65525.9  ...
# 29              70125.2              70789.6              69958.4  ...
# 30              66232.2              64692.2              63472.3  ...
# 31              61547.8              61933.5              61916.4  ...
# 32              88114.3              89830.6              90560.7  ...
# 33               134562               133450               136582  ...
# 34                  NaN                  NaN                  NaN  ...
# 35              79969.2              80550.5              80597.6  ...
# 36              73189.4              73665.9              73691.1  ...
# 37                  NaN                  NaN                  NaN  ...
# 38              42315.3              43287.7              41899.1  ...
# 39                44113              44109.6              44193.7  ...
# 40              45392.6                45535              45111.5  ...
# 41                45680              46037.7              45922.5  ...
# 42              50100.4                49860              49598.5  ...
# 43              56288.9              57242.3              56732.4  ...
# 44              75606.2              75984.2              75529.3  ...
# 45                65511              65224.9              64851.6  ...
# 46              54420.2              54265.9              54365.7  ...
# 47                  NaN                  NaN                  NaN  ...
# 48              53735.2              53900.6              53600.3  ...
#
#                     296                  297                  298  \
# 0   2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00
# 1                813770               810455               826227
# 2                299421               304778               304579
# 3                528577               526670               525678
# 4                337523               333340               332920
# 5                488784               501533               494770
# 6                442189               441058               439178
# 7                863171               838170               804713
# 8                364540               365226               364413
# 9                474627               473162               477369
# 10               393033               386806               392721
# 11               396858               403730               401559
# 12               567269               573270               566979
# 13               729659               735538               719932
# 14               544194               553640               554123
# 15               450373               453155               453783
# 16               367502               366447               367102
# 17               397385               403945               403300
# 18               401911               406930               413132
# 19               643335               655061               645212
# 20          1.24853e+06          1.23018e+06          1.19044e+06
# 21               508405               504867               488211
# 22               519956               520403               515947
# 23               416885               420341               421258
# 24               517489               515391               509006
# 25               361920               368687               369972
# 26               421319               414268               411874
# 27               657974               648147               643769
# 28               496718               507466               513615
# 29               368908               372899               369917
# 30               441364               447629               452040
# 31               427416               432270               434921
# 32               592251               605559               600642
# 33               905951               922687               927735
# 34                  NaN                  NaN                  NaN
# 35               571439               577554               574464
# 36               425263               425804               424942
# 37                  NaN                  NaN                  NaN
# 38               131515               131952               129462
# 39               167490               166796               166640
# 40               165441               165407               166494
# 41               195268               194808               194674
# 42               200858               200969               200116
# 43               290623               291944               291196
# 44               472872               477779               474156
# 45               323122               324357               323278
# 46               258241               258751               258880
# 47                  NaN                  NaN                  NaN
# 48               249294               249771               249152
#
#                     299                  300                  301  \
# 0   2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00
# 1                776894               737275               747611
# 2                306390               301283               303653
# 3                522639               519306               518542
# 4                333657               336302               334765
# 5                432188               427126               423161
# 6                436080               438682               435532
# 7                825336               807124               815512
# 8                367585               369568               371227
# 9                475492               469662               466491
# 10               393255               400182               390589
# 11               405337               398024               396833
# 12               559758               552785               558321
# 13               719751               728698               740048
# 14               559426               565582               563151
# 15               450109               446900               447269
# 16               365861               365886               362423
# 17               407706               404843               406622
# 18               410071               409569               410277
# 19               630659               648969               667450
# 20          1.19405e+06          1.23176e+06          1.25104e+06
# 21               490420               487696               489690
# 22               519410               521705               526270
# 23               415893               413462               409749
# 24               501570               500651               501370
# 25               363114               360934               367017
# 26               413882               424631               422633
# 27               650949               655378               662919
# 28               510619               505499               499906
# 29               374775               372581               372982
# 30               450989               456436               463719
# 31               435568               437333               441446
# 32               601650               605560               605540
# 33               955265               960943          1.01165e+06
# 34                  NaN                  NaN                  NaN
# 35               573932               575132               580408
# 36               423311               423156               422509
# 37                  NaN                  NaN                  NaN
# 38               129658               129504               128401
# 39               165808               164893               165094
# 40               164499               165818               164752
# 41               194855               194553               196199
# 42               200896               198644               202085
# 43               288781               290814               290335
# 44               468983               478576               478489
# 45               322512               321972               323422
# 46               256875               256577               257822
# 47                  NaN                  NaN                  NaN
# 48               247951               248250               248950
#
#                     302                  303                  304  \
# 0   2020-02-01 00:00:00  2020-03-01 00:00:00  2020-04-01 00:00:00
# 1                777640               844989               867841
# 2                304265               304099               283139
# 3                519121               527747               526553
# 4                337760               339215               346840
# 5                467145               461398               494455
# 6                435704               434625               443482
# 7                825249               870107               870627
# 8                371357               370872               386738
# 9                465614               478565               502107
# 10               389901               395082               400695
# 11               402174               404658               389920
# 12               580773               586842               551629
# 13               748877               742876               719836
# 14               548652               550296               547124
# 15               455076               456568               465958
# 16               363699               364658               378747
# 17               406712               412593               405066
# 18               409794               411748               396030
# 19               675653               670075               706263
# 20          1.31317e+06           1.3444e+06          1.34895e+06
# 21               486805               488389               477450
# 22               524048               521753               513397
# 23               414526               414411               400987
# 24               500782               509365               529857
# 25               376713               379837               356915
# 26               422506               426848               435763
# 27               658932               658654               683248
# 28               499775               504904               508543
# 29               373644               376708               376808
# 30               473163               482143               480984
# 31               437879               438596               440354
# 32               610145               614426               607227
# 33          1.01658e+06          1.01398e+06          1.03449e+06
# 34                  NaN                  NaN                  NaN
# 35               586789               591783               584234
# 36               424826               427481               431880
# 37                  NaN                  NaN                  NaN
# 38               128142               129047               125938
# 39               166291               168161               167809
# 40               164949               165685               165561
# 41               194214               198284               200513
# 42               200196               201369               202093
# 43               290309               291356               295640
# 44               479628               488185               480425
# 45               319827               326701               327413
# 46               257101               262444               255891
# 47                  NaN                  NaN                  NaN
# 48               248232               251539               250874
#
#                     305
# 0   2020-05-01 00:00:00
# 1                899831
# 2                295744
# 3                532503
# 4                339408
# 5                466574
# 6                420036
# 7                862209
# 8                369791
# 9                490596
# 10               408018
# 11               402463
# 12               572410
# 13               688761
# 14               563752
# 15               449553
# 16               367809
# 17               422073
# 18               416681
# 19               652895
# 20          1.42852e+06
# 21               480619
# 22               523127
# 23               423031
# 24               513216
# 25               376579
# 26               423193
# 27               664536
# 28               525473
# 29               376155
# 30               498228
# 31               443510
# 32               615207
# 33               937356
# 34                  NaN
# 35               592328
# 36               427978
# 37                  NaN
# 38               134545
# 39               168261
# 40               170198
# 41               197505
# 42               203658
# 43               290621
# 44               479018
# 45               324659
# 46               261006
# 47                  NaN
# 48               251973
#
# [49 rows x 307 columns]

# %%
 # Dropping city of london , not a part of 32 london boroughs
properties = properties.drop(properties.index[1])

# %%
# Dropping index 34 to 49,  also not part of 32 london boroughs
properties = properties.drop(properties.index[33:])

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties = properties.reset_index()

# %%
# Renaming of Columns
properties.iloc[0,0] = 'Boroughs'
properties.iloc[0,1] = 'ID'

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Columns: 307 entries, index to 305
# dtypes: object(307)
# memory usage: 79.3+ KB

# %%
properties.head()
# Out:
#                 index          0                    1                    2  \
# 0            Boroughs         ID  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1  Barking & Dagenham  E09000002              50460.2              51085.8
# 2              Barnet  E09000003              93284.5              93190.2
# 3              Bexley  E09000004              64958.1              64787.9
# 4               Brent  E09000005              71306.6              72022.3
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1                51269              53133.5              53042.2
# 2              92247.5              90762.9                90258
# 3              64367.5              64277.7              63997.1
# 4              72015.8              72965.6                73704
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              53700.3              52113.1              52232.2  ...
# 2              90107.2              91441.2              92361.3  ...
# 3              64252.3              63722.7              64432.6  ...
# 4              74310.5                74127                73547  ...
#
#                    296                  297                  298  \
# 0  2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00
# 1               299421               304778               304579
# 2               528577               526670               525678
# 3               337523               333340               332920
# 4               488784               501533               494770
#
#                    299                  300                  301  \
# 0  2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00
# 1               306390               301283               303653
# 2               522639               519306               518542
# 3               333657               336302               334765
# 4               432188               427126               423161
#
#                    302                  303                  304  \
# 0  2020-02-01 00:00:00  2020-03-01 00:00:00  2020-04-01 00:00:00
# 1               304265               304099               283139
# 2               519121               527747               526553
# 3               337760               339215               346840
# 4               467145               461398               494455
#
#                    305
# 0  2020-05-01 00:00:00
# 1               295744
# 2               532503
# 3               339408
# 4               466574
#
# [5 rows x 307 columns]

# %%
properties.dtypes
# Out:
# index    object
# 0        object
# 1        object
# 2        object
# 3        object
#           ...
# 301      object
# 302      object
# 303      object
# 304      object
# 305      object
# Length: 307, dtype: object

# %%
#set column header : setting first row as header
new_header = properties.iloc[0]
properties = properties.iloc[1:]
properties.columns = new_header

# %%
properties
# Out:
# 0               Boroughs         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1     Barking & Dagenham  E09000002             50460.2             51085.8
# 2                 Barnet  E09000003             93284.5             93190.2
# 3                 Bexley  E09000004             64958.1             64787.9
# 4                  Brent  E09000005             71306.6             72022.3
# 5                Bromley  E09000006             81671.5             81657.6
# 6                 Camden  E09000007              120933              119509
# 7                Croydon  E09000008             69158.2             68951.1
# 8                 Ealing  E09000009             79885.9             80897.1
# 9                Enfield  E09000010             72514.7             73155.2
# 10             Greenwich  E09000011             62300.1             60993.3
# 11               Hackney  E09000012             61296.5             63187.1
# 12  Hammersmith & Fulham  E09000013              124903              122088
# 13              Haringey  E09000014             76287.6             78901.2
# 14                Harrow  E09000015             84769.5             83396.1
# 15              Havering  E09000016             68000.1             69393.5
# 16            Hillingdon  E09000017             73834.8             75031.1
# 17              Hounslow  E09000018             72231.7             71051.6
# 18             Islington  E09000019             92516.5             94342.4
# 19  Kensington & Chelsea  E09000020              182695              182345
# 20  Kingston upon Thames  E09000021             80875.8             81230.1
# 21               Lambeth  E09000022               67771             65381.5
# 22              Lewisham  E09000023             60491.3             60869.3
# 23                Merton  E09000024             82070.6             79982.7
# 24                Newham  E09000025             53539.3             53153.9
# 25             Redbridge  E09000026             72189.6             72141.6
# 26  Richmond upon Thames  E09000027              109326              111103
# 27             Southwark  E09000028             67885.2             64799.1
# 28                Sutton  E09000029               71537             70893.2
# 29         Tower Hamlets  E09000030             59865.2             62318.5
# 30        Waltham Forest  E09000031             61319.4             60252.1
# 31            Wandsworth  E09000032               88559               88641
# 32           Westminster  E09000033              133025              131468
#
# 0  1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1                51269             53133.5             53042.2
# 2              92247.5             90762.9               90258
# 3              64367.5             64277.7             63997.1
# 4              72015.8             72965.6               73704
# 5              81449.3             81124.4             81542.6
# 6               120282              120098              119929
# 7              68712.4               68610             68844.9
# 8              81379.9             82188.9             82077.1
# 9              72190.4             71442.9             70630.8
# 10             61377.8             61927.7               63513
# 11             63593.3             65139.6               66194
# 12              120636              121425              124434
# 13             78521.9             79545.6               79374
# 14             83416.2             83567.9             83853.7
# 15               69368             69444.3             68534.5
# 16             74188.7             73911.4             73117.1
# 17               72098             71890.3             72877.5
# 18             93465.9             93344.5             94346.4
# 19              182879              184177              191474
# 20             81111.5             81672.8             82123.5
# 21             66336.5             66388.8             69035.1
# 22               60288               59471             58551.4
# 23             80661.7             79990.5               80874
# 24             53458.3             54479.8               55804
# 25             72501.4             72228.6             72366.6
# 26              107325              106875              107708
# 27             65763.3             63073.6             64420.5
# 28             70306.8             69411.9             69759.2
# 29             63938.7             66233.2             66432.9
# 30             60871.1             60971.4             61494.2
# 31             87124.8               87026             86518.1
# 32              132260              133370              133911
#
# 0  1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1              53700.3             52113.1             52232.2  ...
# 2              90107.2             91441.2             92361.3  ...
# 3              64252.3             63722.7             64432.6  ...
# 4              74310.5               74127               73547  ...
# 5              82382.8             82898.5             82054.4  ...
# 6               121887              124028              125530  ...
# 7              69052.5             69142.5             68993.4  ...
# 8              81630.7             82352.2             82706.7  ...
# 9              71348.3             71837.5             72237.9  ...
# 10             64751.6             65486.3             65076.4  ...
# 11             66921.2             68390.8             68096.8  ...
# 12              126175              124382              123625  ...
# 13             79956.4             80746.3             81217.7  ...
# 14             84173.2             84226.7             84430.6  ...
# 15             68464.6             68680.8             69023.4  ...
# 16               74005             74671.1             74967.9  ...
# 17             72331.1             73717.8             74479.9  ...
# 18             97428.9             98976.1             98951.2  ...
# 19              197266              197963              198037  ...
# 20             82205.7             82525.8             83342.8  ...
# 21             68881.2             69608.7               68840  ...
# 22             58041.4             58126.4             58151.3  ...
# 23             80704.9             81055.9             80781.1  ...
# 24             56067.8             55458.3             54709.4  ...
# 25             72279.4             72880.8             73275.2  ...
# 26              112865              114657              112320  ...
# 27             64155.8             67024.7             65525.9  ...
# 28             70125.2             70789.6             69958.4  ...
# 29             66232.2             64692.2             63472.3  ...
# 30             61547.8             61933.5             61916.4  ...
# 31             88114.3             89830.6             90560.7  ...
# 32              134562              133450              136582  ...
#
# 0  2019-08-01 00:00:00 2019-09-01 00:00:00 2019-10-01 00:00:00  \
# 1               299421              304778              304579
# 2               528577              526670              525678
# 3               337523              333340              332920
# 4               488784              501533              494770
# 5               442189              441058              439178
# 6               863171              838170              804713
# 7               364540              365226              364413
# 8               474627              473162              477369
# 9               393033              386806              392721
# 10              396858              403730              401559
# 11              567269              573270              566979
# 12              729659              735538              719932
# 13              544194              553640              554123
# 14              450373              453155              453783
# 15              367502              366447              367102
# 16              397385              403945              403300
# 17              401911              406930              413132
# 18              643335              655061              645212
# 19         1.24853e+06         1.23018e+06         1.19044e+06
# 20              508405              504867              488211
# 21              519956              520403              515947
# 22              416885              420341              421258
# 23              517489              515391              509006
# 24              361920              368687              369972
# 25              421319              414268              411874
# 26              657974              648147              643769
# 27              496718              507466              513615
# 28              368908              372899              369917
# 29              441364              447629              452040
# 30              427416              432270              434921
# 31              592251              605559              600642
# 32              905951              922687              927735
#
# 0  2019-11-01 00:00:00 2019-12-01 00:00:00 2020-01-01 00:00:00  \
# 1               306390              301283              303653
# 2               522639              519306              518542
# 3               333657              336302              334765
# 4               432188              427126              423161
# 5               436080              438682              435532
# 6               825336              807124              815512
# 7               367585              369568              371227
# 8               475492              469662              466491
# 9               393255              400182              390589
# 10              405337              398024              396833
# 11              559758              552785              558321
# 12              719751              728698              740048
# 13              559426              565582              563151
# 14              450109              446900              447269
# 15              365861              365886              362423
# 16              407706              404843              406622
# 17              410071              409569              410277
# 18              630659              648969              667450
# 19         1.19405e+06         1.23176e+06         1.25104e+06
# 20              490420              487696              489690
# 21              519410              521705              526270
# 22              415893              413462              409749
# 23              501570              500651              501370
# 24              363114              360934              367017
# 25              413882              424631              422633
# 26              650949              655378              662919
# 27              510619              505499              499906
# 28              374775              372581              372982
# 29              450989              456436              463719
# 30              435568              437333              441446
# 31              601650              605560              605540
# 32              955265              960943         1.01165e+06
#
# 0  2020-02-01 00:00:00 2020-03-01 00:00:00 2020-04-01 00:00:00  \
# 1               304265              304099              283139
# 2               519121              527747              526553
# 3               337760              339215              346840
# 4               467145              461398              494455
# 5               435704              434625              443482
# 6               825249              870107              870627
# 7               371357              370872              386738
# 8               465614              478565              502107
# 9               389901              395082              400695
# 10              402174              404658              389920
# 11              580773              586842              551629
# 12              748877              742876              719836
# 13              548652              550296              547124
# 14              455076              456568              465958
# 15              363699              364658              378747
# 16              406712              412593              405066
# 17              409794              411748              396030
# 18              675653              670075              706263
# 19         1.31317e+06          1.3444e+06         1.34895e+06
# 20              486805              488389              477450
# 21              524048              521753              513397
# 22              414526              414411              400987
# 23              500782              509365              529857
# 24              376713              379837              356915
# 25              422506              426848              435763
# 26              658932              658654              683248
# 27              499775              504904              508543
# 28              373644              376708              376808
# 29              473163              482143              480984
# 30              437879              438596              440354
# 31              610145              614426              607227
# 32         1.01658e+06         1.01398e+06         1.03449e+06
#
# 0  2020-05-01 00:00:00
# 1               295744
# 2               532503
# 3               339408
# 4               466574
# 5               420036
# 6               862209
# 7               369791
# 8               490596
# 9               408018
# 10              402463
# 11              572410
# 12              688761
# 13              563752
# 14              449553
# 15              367809
# 16              422073
# 17              416681
# 18              652895
# 19         1.42852e+06
# 20              480619
# 21              523127
# 22              423031
# 23              513216
# 24              376579
# 25              423193
# 26              664536
# 27              525473
# 28              376155
# 29              498228
# 30              443510
# 31              615207
# 32              937356
#
# [32 rows x 307 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties = pd.melt(properties, id_vars=['ID','Boroughs'])

# %%
properties.set_index('ID')
# Out:
#                      Boroughs          0    value
# ID
# E09000002  Barking & Dagenham 1995-01-01  50460.2
# E09000003              Barnet 1995-01-01  93284.5
# E09000004              Bexley 1995-01-01  64958.1
# E09000005               Brent 1995-01-01  71306.6
# E09000006             Bromley 1995-01-01  81671.5
# ...                       ...        ...      ...
# E09000029              Sutton 2020-05-01   376155
# E09000030       Tower Hamlets 2020-05-01   498228
# E09000031      Waltham Forest 2020-05-01   443510
# E09000032          Wandsworth 2020-05-01   615207
# E09000033         Westminster 2020-05-01   937356
#
# [9760 rows x 3 columns]

# %%
properties = properties.rename(columns={'value':'Price', 0:'Date'})

# %%
properties['Date']
# Out:
# 0      1995-01-01
# 1      1995-01-01
# 2      1995-01-01
# 3      1995-01-01
# 4      1995-01-01
#           ...
# 9755   2020-05-01
# 9756   2020-05-01
# 9757   2020-05-01
# 9758   2020-05-01
# 9759   2020-05-01
# Name: Date, Length: 9760, dtype: datetime64[ns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#convert datatypes to string, datetime
properties['Boroughs'] = properties['Boroughs'].astype('category')
properties['Date'] = pd.to_datetime(properties['Date'])
properties['Price'] = pd.to_numeric(properties['Price'])
properties['Year'] = pd. DatetimeIndex(properties['Date']).year
properties['Month'] = pd. DatetimeIndex(properties['Date']).month

# Round off Price to 2 decimals
properties['Price'] = round(properties['Price'],2)

# %%
properties
# Out:
#              ID            Boroughs       Date      Price  Year  Month
# 0     E09000002  Barking & Dagenham 1995-01-01   50460.23  1995      1
# 1     E09000003              Barnet 1995-01-01   93284.52  1995      1
# 2     E09000004              Bexley 1995-01-01   64958.09  1995      1
# 3     E09000005               Brent 1995-01-01   71306.57  1995      1
# 4     E09000006             Bromley 1995-01-01   81671.48  1995      1
# ...         ...                 ...        ...        ...   ...    ...
# 9755  E09000029              Sutton 2020-05-01  376154.74  2020      5
# 9756  E09000030       Tower Hamlets 2020-05-01  498227.84  2020      5
# 9757  E09000031      Waltham Forest 2020-05-01  443509.80  2020      5
# 9758  E09000032          Wandsworth 2020-05-01  615207.17  2020      5
# 9759  E09000033         Westminster 2020-05-01  937356.00  2020      5
#
# [9760 rows x 6 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
new_properties = properties[['ID', 'Boroughs', 'Year', 'Price']]

# %%
new_properties
# Out:
#              ID            Boroughs  Year      Price
# 0     E09000002  Barking & Dagenham  1995   50460.23
# 1     E09000003              Barnet  1995   93284.52
# 2     E09000004              Bexley  1995   64958.09
# 3     E09000005               Brent  1995   71306.57
# 4     E09000006             Bromley  1995   81671.48
# ...         ...                 ...   ...        ...
# 9755  E09000029              Sutton  2020  376154.74
# 9756  E09000030       Tower Hamlets  2020  498227.84
# 9757  E09000031      Waltham Forest  2020  443509.80
# 9758  E09000032          Wandsworth  2020  615207.17
# 9759  E09000033         Westminster  2020  937356.00
#
# [9760 rows x 4 columns]

# %%
# list of 32 boroughs are stored in bor
bor = new_properties['Boroughs'].unique()

# %%
bor
# Out:
# ['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', ..., 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']
# Length: 32
# Categories (32, object): ['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', ..., 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']

# %%
#function to calculate ratio of average prices of boroughs of 1995 and 2019 for each borough
def bor_ratio(i):
    lon_bor = new_properties[new_properties['Boroughs']== bor[i]]
    lon_bor = lon_bor.groupby('Year')['Price'].mean()
    lon_bor = round(lon_bor,2)
    bor95 = lon_bor[lon_bor.index == 1995]
    bor19 = lon_bor[lon_bor.index == 2019]
    avgbor = bor95.values/(bor19.values)*100
    return avgbor

# %%
#assigning the ratios of each borough by running the function bor_ratio()
avgbd = bor_ratio(0)
avgbar = bor_ratio(1)
avgbex = bor_ratio(2)
avgbre = bor_ratio(3)
avgbro = bor_ratio(4)
avgcam = bor_ratio(5)
avgcro = bor_ratio(6)
avgeal = bor_ratio(7)
avgenf = bor_ratio(8)
avggre = bor_ratio(9)
avghac = bor_ratio(10)
avgham = bor_ratio(11)
avghar = bor_ratio(12)
avgharr = bor_ratio(13)
avghav = bor_ratio(14)
avghil = bor_ratio(15)
avghou = bor_ratio(16)
avgisl = bor_ratio(17)
avgken = bor_ratio(18)
avgkut = bor_ratio(19)
avglam = bor_ratio(20)
avglew = bor_ratio(21)
avgmer = bor_ratio(22)
avgnew = bor_ratio(23)
avgred = bor_ratio(24)
avgrut = bor_ratio(25)
avgsou = bor_ratio(26)
avgsut = bor_ratio(27)
avgtow = bor_ratio(28)
avgfor = bor_ratio(29)
avgwan = bor_ratio(30)
avgwes = bor_ratio(31)

# %%
# average values of all 32 London Boroughs are stored in a list called avg
avg = [avgbd, avgbar, avgbex, avgbre,avgbro, avgcam, avgcro,avgeal, avgenf, avggre, avghac, avgham, avghar, avgharr, 
       avghav,avghil, avghou,avgisl,avgken,avgkut,avglam, avglew, avgmer, avgnew, avgred, avgrut, avgsou, avgsut,avgtow,
       avgfor, avgwan,avgwes]
for i in range(len(bor)):
    print('The Ratio of Average Prices between 1995 and 2019 of %s is %f' %(bor[i], avg[i]))
# Out:
# The Ratio of Average Prices between 1995 and 2019 of Barking & Dagenham is 17.352466
# The Ratio of Average Prices between 1995 and 2019 of Barnet is 17.665618
# The Ratio of Average Prices between 1995 and 2019 of Bexley is 19.085647
# The Ratio of Average Prices between 1995 and 2019 of Brent is 15.390480
# The Ratio of Average Prices between 1995 and 2019 of Bromley is 18.780038
# The Ratio of Average Prices between 1995 and 2019 of Camden is 14.299761
# The Ratio of Average Prices between 1995 and 2019 of Croydon is 18.860316
# The Ratio of Average Prices between 1995 and 2019 of Ealing is 17.174116
# The Ratio of Average Prices between 1995 and 2019 of Enfield is 18.324273
# The Ratio of Average Prices between 1995 and 2019 of Greenwich is 16.127171
# The Ratio of Average Prices between 1995 and 2019 of Hackney is 11.882279
# The Ratio of Average Prices between 1995 and 2019 of Hammersmith & Fulham is 17.081779
# The Ratio of Average Prices between 1995 and 2019 of Haringey is 14.633633
# The Ratio of Average Prices between 1995 and 2019 of Harrow is 18.590401
# The Ratio of Average Prices between 1995 and 2019 of Havering is 18.718532
# The Ratio of Average Prices between 1995 and 2019 of Hillingdon is 18.232150
# The Ratio of Average Prices between 1995 and 2019 of Hounslow is 18.194090
# The Ratio of Average Prices between 1995 and 2019 of Islington is 15.057288
# The Ratio of Average Prices between 1995 and 2019 of Kensington & Chelsea is 15.506460
# The Ratio of Average Prices between 1995 and 2019 of Kingston upon Thames is 17.003236
# The Ratio of Average Prices between 1995 and 2019 of Lambeth is 13.395597
# The Ratio of Average Prices between 1995 and 2019 of Lewisham is 14.388100
# The Ratio of Average Prices between 1995 and 2019 of Merton is 15.903171
# The Ratio of Average Prices between 1995 and 2019 of Newham is 14.994682
# The Ratio of Average Prices between 1995 and 2019 of Redbridge is 17.592448
# The Ratio of Average Prices between 1995 and 2019 of Richmond upon Thames is 16.905787
# The Ratio of Average Prices between 1995 and 2019 of Southwark is 12.871385
# The Ratio of Average Prices between 1995 and 2019 of Sutton is 18.901864
# The Ratio of Average Prices between 1995 and 2019 of Tower Hamlets is 14.517245
# The Ratio of Average Prices between 1995 and 2019 of Waltham Forest is 14.234542
# The Ratio of Average Prices between 1995 and 2019 of Wandsworth is 15.091252
# The Ratio of Average Prices between 1995 and 2019 of Westminster is 13.993707

# %%
#bar plotting of ratio of each borrough
fig, ax= plt.subplots(sharey=True)
ax.bar(bor[0], avgbd)
ax.bar(bor[1], avgbar)
ax.bar(bor[2], avgbex)
ax.bar(bor[3], avgbre)
ax.bar(bor[4], avgbro)
ax.bar(bor[5], avgcam)
ax.bar(bor[6], avgcro)
ax.bar(bor[7], avgeal)
ax.bar(bor[8], avgenf)
ax.bar(bor[9], avggre)
ax.bar(bor[10], avghac)
ax.bar(bor[11], avgham)
ax.bar(bor[12], avghar)
ax.bar(bor[13], avgharr)
ax.bar(bor[14], avghav)
ax.bar(bor[15], avghil)
ax.bar(bor[16], avghou)
ax.bar(bor[17], avgisl)
ax.bar(bor[18], avgken)
ax.bar(bor[19], avgkut)
ax.bar(bor[20], avglam)
ax.bar(bor[21], avglew)
ax.bar(bor[22], avgmer)
ax.bar(bor[23], avgnew)
ax.bar(bor[24], avgred)
ax.bar(bor[25], avgrut)
ax.bar(bor[26], avgsou)
ax.bar(bor[27], avgsut)
ax.bar(bor[28], avgtow)
ax.bar(bor[29], avgfor)
ax.bar(bor[30], avgwan)
ax.bar(bor[31], avgwes)
ax.set_xlabel('London Boroughs')
ax.set_ylabel('Ratio of Average Prices of 1995 and 2019')
ax.set_title('London Real Estate')
plt.ylim(10,20)
ax.set_xticklabels(bor.categories, rotation=90)
plt.savefig('ratio_london.png')
plt.show()

# %%
# function to return the average prices of all boroughs year-wise from 1995 to 2020
def bor_avg(i):
    lon_bor = new_properties[new_properties['Boroughs']== bor[i]]
    lon_bor = lon_bor.groupby('Year')['Price'].mean()
    lon_bor = round(lon_bor,2)
    return lon_bor

# %%
#assigning the average prices of each borough by executing the function bor_avg()
bor_bd = bor_avg(0)
bor_barnet = bor_avg(1)
bor_bexley = bor_avg(2)
bor_brent = bor_avg(3)
bor_bromley = bor_avg(4)
bor_camden = bor_avg(5)
bor_Croydon = bor_avg(6)
bor_Ealing = bor_avg(7)
bor_Enfield = bor_avg(8)
bor_Greenwich = bor_avg(9)
bor_Hackney = bor_avg(10)
bor_hamful = bor_avg(11)
bor_Haringey = bor_avg(12)
bor_Harrow = bor_avg(13)
bor_Havering = bor_avg(14)
bor_Hillingdon = bor_avg(15)
bor_Hounslow =  bor_avg(16)
bor_Islington = bor_avg(17)
bor_kenche =  bor_avg(18)
bor_kut = bor_avg(19)
bor_lam = bor_avg(20)
bor_Lewisham = bor_avg(21)
bor_Merton = bor_avg(22)
bor_Newham = bor_avg(23)
bor_Redbridge = bor_avg(24)
bor_rut = bor_avg(25)
bor_Southwark = bor_avg(26)
bor_sut = bor_avg(27)
bor_tow = bor_avg(28)
bor_forest = bor_avg(29)
bor_wands = bor_avg(30)
bor_west = bor_avg(31)

# %%
#line plot of each individual boroughs
fig, ax= plt.subplots(sharey=True)
ax.plot(bor_bd, marker='o', color ='black')
ax.plot(bor_barnet, marker='v')
ax.plot(bor_bexley, linestyle='--')
ax.plot(bor_brent, linestyle='--')
ax.plot(bor_bromley,linestyle='--')
ax.plot(bor_camden, marker='o', color='orange')# Camden
ax.plot(bor_Croydon)
ax.plot(bor_Ealing)
ax.plot(bor_Enfield)
ax.plot(bor_Greenwich, marker='v')
ax.plot(bor_Hackney)
ax.plot(bor_hamful)
ax.plot(bor_Haringey)
ax.plot(bor_Harrow)
ax.plot(bor_Havering, marker='v')
ax.plot(bor_Hillingdon)
ax.plot(bor_Hounslow)
ax.plot(bor_Islington)
ax.plot(bor_kenche, linestyle='--',marker='o', color='b') #Kensington & Chelsea
ax.plot(bor_kut,linestyle='--')
ax.plot(bor_lam)
ax.plot(bor_Lewisham, marker='v')
ax.plot(bor_Merton,linestyle='--')
ax.plot(bor_Newham,linestyle='--')
ax.plot(bor_Redbridge, linestyle='--')
ax.plot(bor_rut,linestyle='--')
ax.plot(bor_Southwark, linestyle='--')
ax.plot(bor_sut)
ax.plot(bor_tow)
ax.plot(bor_forest)
ax.plot(bor_wands, marker='v')
ax.plot(bor_west, marker='v',linestyle='--', color='green') # Westminster
ax.set_xlabel('Year')
ax.set_ylabel('Average Price')
ax.set_title('London Boroughs')
ax.annotate("Kensington & Chelsea",  xy=(0.95,0.85), xycoords='axes fraction', xytext=(0.2, 0.9),arrowprops={'arrowstyle': '->', 'color': 'orange'})
ax.annotate("Westminster",  xy=(0.75,0.65), xycoords='axes fraction', xytext=(0.2, 0.7),arrowprops={'arrowstyle': '->', 'color': 'orange'})
ax.annotate("Camden",  xy=(0.95,0.6), xycoords='axes fraction', xytext=(0.2, 0.6),arrowprops={'arrowstyle': '->', 'color': 'orange'})
ax.annotate("Barking & Dagenham",  xy=(0.95,0.2), xycoords='axes fraction', xytext=(0.4, 0.05),arrowprops={'arrowstyle': '->', 'color': 'orange'})
plt.savefig('properties.png')
plt.show()

# %%
new_properties.to_csv('london.csv')

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ###### There are total 32 in no. of Boroughs in London, namely Barking & Dagenham, Barnet, Bexley, Brent,Bromley, Camden, Croydon, Ealing, Enfield ,Greenwich ,Hackney, Hammersmith & Fulham, Haringey, Harrow, Havering, Hillingdon,Hounslow, Islington, Kensington & Chelsea, Kingston upon Thames, Lambeth, Lewisham, Merton, Newham, Redbridge, Richmond upon Thames, Southwark, Sutton, Tower Hamlets, Waltham Forest, Wandsworth and Westminster.
#     The most expensive borough in London (according to the rise of average prices from 1995 to 2019) is Kensington & Chelsea, followed by Westminster and Camden and the least expensive is Barking & Dagenham.

# %% [markdown]
# According to the ratio of average price of 1995 and 2019, Bexley, Sutton boroughs rank highest
